# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
a=pd.read_csv("swiggy.csv")
a
# Out:
#           ID                    Area       City                Restaurant  \
# 0        211             Koramangala  Bangalore               Tandoor Hut
# 1        221             Koramangala  Bangalore             Tunday Kababi
# 2        246               Jogupalya  Bangalore                   Kim Lee
# 3        248             Indiranagar  Bangalore         New Punjabi Hotel
# 4        249             Indiranagar  Bangalore                       Nh8
# ...      ...                     ...        ...                       ...
# 8675  464626  Panjarapole Cross Road  Ahmedabad                Malt Pizza
# 8676  465835                  Rohini      Delhi  Jay Mata Ji Home Kitchen
# 8677  465872                  Rohini      Delhi      Chinese Kitchen King
# 8678  465990                  Rohini      Delhi    Shree Ram Paratha Wala
# 8679  466488             Navrangpura  Ahmedabad              Sassy Street
#
#       Price  Avg ratings  Total ratings  \
# ...

# %%
a.head(1)
# Out:
#     ID         Area       City   Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore  Tandoor Hut  300.0          4.4
#
#    Total ratings                                  Food type    Address  \
# 0            100  Biryani,Chinese,North Indian,South Indian  5Th Block
#
#    Delivery time
# 0             59

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   float64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 678.3+ KB

# %%
a["ID"].value_counts()
# Out:
# ID
# 211       1
# 441413    1
# 441787    1
# 441784    1
# 441777    1
#          ..
# 289953    1
# 289868    1
# 289697    1
# 289696    1
# 466488    1
# Name: count, Length: 8680, dtype: int64

# %%
a["ID"].value_counts(normalize= True)*100
# Out:
# ID
# 211       0.011521
# 441413    0.011521
# 441787    0.011521
# 441784    0.011521
# 441777    0.011521
#             ...
# 289953    0.011521
# 289868    0.011521
# 289697    0.011521
# 289696    0.011521
# 466488    0.011521
# Name: proportion, Length: 8680, dtype: float64

# %%
a["Area"].value_counts()
# Out:
# Area
# Rohini                    257
# Chembur                   208
# Kothrud                   149
# Andheri East              135
# Navrangpura               132
#                          ...
# Shakurpur                   1
# Magob                       1
# Bosepukur                   1
# Ambegaon                    1
# Panjarapole Cross Road      1
# Name: count, Length: 833, dtype: int64

# %%
a["Area"].value_counts(normalize= True)*100
# Out:
# Area
# Rohini                    2.960829
# Chembur                   2.396313
# Kothrud                   1.716590
# Andheri East              1.555300
# Navrangpura               1.520737
#                             ...
# Shakurpur                 0.011521
# Magob                     0.011521
# Bosepukur                 0.011521
# Ambegaon                  0.011521
# Panjarapole Cross Road    0.011521
# Name: proportion, Length: 833, dtype: float64

# %%
a["Area"].value_counts(normalize= True).sort_index(ascending=True)*100
# Out:
# Area
#  Akhbar Nagar Circle               0.011521
#  Begumpet                          0.011521
# 26                                 0.011521
# 3Rd Block Jayanagar                0.011521
# A Unit Of M/S Cohort  Ruby Area    0.011521
#                                      ...
# Yamuna Nagar                       0.034562
# Yerawada                           0.080645
# Yoginagar Society                  0.011521
# Yousufguda                         0.023041
# Zamistanpur                        0.023041
# Name: proportion, Length: 833, dtype: float64

# %%
a['City'].value_counts()
# Out:
# City
# Kolkata      1346
# Mumbai       1277
# Chennai      1106
# Pune         1090
# Hyderabad    1075
# Bangalore     946
# Ahmedabad     717
# Delhi         611
# Surat         512
# Name: count, dtype: int64

# %%
a["City"].value_counts(normalize= True)*100
# Out:
# City
# Kolkata      15.506912
# Mumbai       14.711982
# Chennai      12.741935
# Pune         12.557604
# Hyderabad    12.384793
# Bangalore    10.898618
# Ahmedabad     8.260369
# Delhi         7.039171
# Surat         5.898618
# Name: proportion, dtype: float64

# %%
a['Restaurant'].value_counts()
# Out:
# Restaurant
# La Pino'Z Pizza           13
# Nic Natural Ice Creams    10
# Baskin Robbins            10
# Subway                    10
# Kfc                        9
#                           ..
# Home Factory               1
# Meals And Bowls            1
# Waffle Dreams              1
# Pratik Restaurant          1
# Sassy Street               1
# Name: count, Length: 7865, dtype: int64

# %%
a["Restaurant"].value_counts(normalize= True).sort_index(ascending=True)*100
# Out:
# Restaurant
#  Conclave At Afraa                  0.011521
#  Hotel Rangda                       0.011521
#  Kishori Lal Paan                   0.011521
#  Momozon                            0.011521
#  Sahadeva Reddy'S Biryani Durbar    0.011521
#                                       ...
# Zouq Fusion Foods                   0.011521
# Zoya Biriyani                       0.011521
# Zuka                                0.011521
# Zwarma                              0.011521
# Zyqa Restaurant                     0.011521
# Name: proportion, Length: 7865, dtype: float64

# %%
a["Price"].value_counts()
# Out:
# Price
# 300.0    1776
# 200.0    1774
# 250.0     968
# 400.0     838
# 500.0     605
#          ...
# 196.0       1
# 355.0       1
# 398.0       1
# 620.0       1
# 5.0         1
# Name: count, Length: 120, dtype: int64

# %%
a["Price"].value_counts(normalize= True).sort_index(ascending=True)*100
# Out:
# Price
# 0.0       0.057604
# 1.0       0.046083
# 2.0       0.023041
# 5.0       0.011521
# 10.0      0.023041
#             ...
# 1700.0    0.011521
# 1800.0    0.034562
# 1900.0    0.034562
# 2000.0    0.046083
# 2500.0    0.034562
# Name: proportion, Length: 120, dtype: float64

# %%
a["Avg ratings"].value_counts()
# Out:
# Avg ratings
# 2.9    3279
# 4.3     792
# 4.2     754
# 4.1     700
# 4.4     573
# 4.0     524
# 3.9     421
# 4.5     338
# 3.8     313
# 3.7     207
# 4.6     166
# 3.6     118
# 4.7      96
# 3.5      95
# 3.4      60
# 3.3      51
# 3.2      45
# 4.8      29
# 3.1      26
# 3.0      25
# 5.0      18
# 2.8      15
# 4.9      15
# 2.7      11
# 2.2       3
# 2.6       2
# 2.5       1
# 2.3       1
# 2.0       1
# 2.4       1
# Name: count, dtype: int64

# %%
a["Avg ratings"].value_counts(normalize= True).sort_index(ascending=True)*100
# Out:
# Avg ratings
# 2.0     0.011521
# 2.2     0.034562
# 2.3     0.011521
# 2.4     0.011521
# 2.5     0.011521
# 2.6     0.023041
# 2.7     0.126728
# 2.8     0.172811
# 2.9    37.776498
# 3.0     0.288018
# 3.1     0.299539
# 3.2     0.518433
# 3.3     0.587558
# 3.4     0.691244
# 3.5     1.094470
# 3.6     1.359447
# 3.7     2.384793
# 3.8     3.605991
# 3.9     4.850230
# 4.0     6.036866
# 4.1     8.064516
# 4.2     8.686636
# 4.3     9.124424
# 4.4     6.601382
# 4.5     3.894009
# 4.6     1.912442
# 4.7     1.105991
# 4.8     0.334101
# 4.9     0.172811
# 5.0     0.207373
# Name: proportion, dtype: float64

# %%
a["Total ratings"].value_counts()
# Out:
# Total ratings
# 80       3273
# 100      1987
# 20       1440
# 50        985
# 500       568
# 1000      407
# 5000       14
# 10000       6
# Name: count, dtype: int64

# %%
a["Total ratings"].value_counts(normalize= True)*100
# Out:
# Total ratings
# 80       37.707373
# 100      22.891705
# 20       16.589862
# 50       11.347926
# 500       6.543779
# 1000      4.688940
# 5000      0.161290
# 10000     0.069124
# Name: proportion, dtype: float64

# %%
a["Food type"].value_counts()
# Out:
# Food type
# Indian                                                      389
# Chinese                                                     277
# North Indian                                                246
# Fast Food                                                   240
# South Indian                                                228
#                                                            ...
# Andhra,South Indian,North Indian,Biryani                      1
# Healthy Food  Juices  Continental                             1
# Bengali  Indian  Combo                                        1
# South Indian,Indian,North Indian,Chinese,Biryani,Tandoor      1
# Chaat,Snacks,Chinese                                          1
# Name: count, Length: 3734, dtype: int64

# %%
a["Food type"].value_counts(normalize= True)*100
# Out:
# Food type
# Indian                                                      4.481567
# Chinese                                                     3.191244
# North Indian                                                2.834101
# Fast Food                                                   2.764977
# South Indian                                                2.626728
#                                                               ...
# Andhra,South Indian,North Indian,Biryani                    0.011521
# Healthy Food  Juices  Continental                           0.011521
# Bengali  Indian  Combo                                      0.011521
# South Indian,Indian,North Indian,Chinese,Biryani,Tandoor    0.011521
# Chaat,Snacks,Chinese                                        0.011521
# Name: proportion, Length: 3734, dtype: float64

# %%
a["Address"].value_counts()
# Out:
# Address
# Rohini                                 229
# Chembur                                166
# Kothrud                                158
# Kurla                                  138
# Navrangpura                            136
#                                       ...
# Punjagutta                               1
# Motilal Nehru Road                       1
# Ib Block Broadway Mall Sector            1
# S.P. Mukherjee Road Southern Aveneu      1
# Sanjay Nagar New Bel Road                1
# Name: count, Length: 2339, dtype: int64

# %%
a["Address"].value_counts(normalize= True)*100
# Out:
# Address
# Rohini                                 2.638249
# Chembur                                1.912442
# Kothrud                                1.820276
# Kurla                                  1.589862
# Navrangpura                            1.566820
#                                          ...
# Punjagutta                             0.011521
# Motilal Nehru Road                     0.011521
# Ib Block Broadway Mall Sector          0.011521
# S.P. Mukherjee Road Southern Aveneu    0.011521
# Sanjay Nagar New Bel Road              0.011521
# Name: proportion, Length: 2339, dtype: float64

# %%
a["Delivery time"].value_counts()
# Out:
# Delivery time
# 52     274
# 47     265
# 49     263
# 46     252
# 45     246
#       ...
# 21       1
# 109      1
# 100      1
# 20       1
# 22       1
# Name: count, Length: 81, dtype: int64

# %%
a["Delivery time"].value_counts(normalize= True)*100
# Out:
# Delivery time
# 52     3.156682
# 47     3.052995
# 49     3.029954
# 46     2.903226
# 45     2.834101
#          ...
# 21     0.011521
# 109    0.011521
# 100    0.011521
# 20     0.011521
# 22     0.011521
# Name: proportion, Length: 81, dtype: float64

# %%
a['Price'].describe()
# Out:
# count    8680.000000
# mean      348.444470
# std       230.940074
# min         0.000000
# 25%       200.000000
# 50%       300.000000
# 75%       400.000000
# max      2500.000000
# Name: Price, dtype: float64

# %%
a['Avg ratings'].describe()
# Out:
# count    8680.000000
# mean        3.655104
# std         0.647629
# min         2.000000
# 25%         2.900000
# 50%         3.900000
# 75%         4.200000
# max         5.000000
# Name: Avg ratings, dtype: float64

# %%
a['Total ratings'].describe()
# Out:
# count     8680.000000
# mean       156.634793
# std        391.448014
# min         20.000000
# 25%         50.000000
# 50%         80.000000
# 75%        100.000000
# max      10000.000000
# Name: Total ratings, dtype: float64

# %%
sns.countplot(a, x='City')
# Out:
# <Axes: xlabel='City', ylabel='count'>

# %%
sns.countplot(a, x='Area')
# Out:
# <Axes: xlabel='Area', ylabel='count'>

# %%
sns.countplot(a, x='ID', hue='City')
plt.title('swiggy')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 2
#       1 sns.countplot(a, x='ID', hue='City')
# ----> 2 plt.title('swiggy')
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
sns.countplot(a, x='City', hue='Delivery time')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 sns.countplot(a, x='City', hue='Delivery time')
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
# ...

# %%
sns.histplot(a, x='City', hue='Price', kde=True)
plt.title('survival count by age')
plt.show()
# Out:
# C:\Users\PC\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 2
#       1 sns.histplot(a, x='City', hue='Price', kde=True)
# ----> 2 plt.title('survival count by age')
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\matplotlib\_api\__init__.py:217, in caching_module_getattr.<locals>.__getattr__(name)
#     215 if name in props:
#     216     return props[name].__get__(instance)
# --> 217 raise AttributeError(
#     218     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'title'

# %%
sns.kdeplot(a, x='Restaurant', hue='Delivery time')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 sns.kdeplot(a, x='Restaurant', hue='Delivery time')
#
# File ~\anaconda3\Lib\site-packages\seaborn\distributions.py:1695, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1692 if ax is None:
#    1693     ax = plt.gca()
# -> 1695 p._attach(ax, allowed_types=["numeric", "datetime"], log_scale=log_scale)
#    1697 method = ax.fill_between if fill else ax.plot
#    1698 color = _default_color(method, hue, color, kwargs)
#
# File ~\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1211, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1206     if var_type not in allowed_types:
# ...

# %%
sns.displot(data=a, x='City', hue='Price', kde=True)
# Out:
# C:\Users\PC\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
